# %% [markdown]
# <a href="https://colab.research.google.com/github/R-Duff/Introduction-to-Quantum-Computing/blob/main/Github_Shor's_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- Install dependencies if not already installed ---
import sys
# !{sys.executable} -m pip install qiskit>=0.46.0 qiskit-aer>=0.12.0
# Out:
# Found existing installation: qiskit 2.1.2
# Uninstalling qiskit-2.1.2:
#   Successfully uninstalled qiskit-2.1.2
# WARNING: Skipping qiskit-aer as it is not installed.
# WARNING: Skipping qiskit-terra as it is not installed.
# WARNING: Skipping qiskit-ibmq-provider as it is not installed.
# Collecting qiskit[all]
#   Using cached qiskit-2.1.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit[all]) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in /usr/local/lib/python3.12/dist-packages (from qiskit[all]) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit[all]) (1.16.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit[all]) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit[all]) (5.5.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit[all]) (4.15.0)
# Requirement already satisfied: qiskit-qasm3-import>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit[all]) (0.6.0)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.12/dist-packages (from qiskit[all]) (3.10.0)
# Requirement already satisfied: pydot in /usr/local/lib/python3.12/dist-packages (from qiskit[all]) (3.0.4)
# Requirement already satisfied: Pillow>=4.2.1 in /usr/local/lib/python3.12/dist-packages (from qiskit[all]) (11.3.0)
# Requirement already satisfied: pylatexenc>=1.4 in /usr/local/lib/python3.12/dist-packages (from qiskit[all]) (2.10)
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from qiskit[all]) (0.13.2)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.12/dist-packages (from qiskit[all]) (1.13.3)
# Requirement already satisfied: z3-solver>=4.7 in /usr/local/lib/python3.12/dist-packages (from qiskit[all]) (4.15.3.0)
# Requirement already satisfied: python-constraint>=1.4 in /usr/local/lib/python3.12/dist-packages (from qiskit[all]) (1.4.0)
# Requirement already satisfied: symengine<0.14,>=0.11 in /usr/local/lib/python3.12/dist-packages (from qiskit[all]) (0.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[all]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[all]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[all]) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[all]) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[all]) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[all]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[all]) (2.9.0.post0)
# Requirement already satisfied: openqasm3<2.0,>=0.4 in /usr/local/lib/python3.12/dist-packages (from openqasm3[parser]<2.0,>=0.4->qiskit-qasm3-import>=0.1.0->qiskit[all]) (1.0.1)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn>=0.9.0->qiskit[all]) (2.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.3->qiskit[all]) (1.3.0)
# Requirement already satisfied: antlr4_python3_runtime<4.14,>=4.7 in /usr/local/lib/python3.12/dist-packages (from openqasm3[parser]<2.0,>=0.4->qiskit-qasm3-import>=0.1.0->qiskit[all]) (4.9.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[all]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[all]) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->qiskit[all]) (1.17.0)
# Using cached qiskit-2.1.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.4 MB)
# Installing collected packages: qiskit
# Successfully installed qiskit-2.1.2
# Collecting qiskit-aer
#   Using cached qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Requirement already satisfied: qiskit>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (2.1.2)
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (2.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (1.16.1)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer) (0.17.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer) (5.5.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer) (4.15.0)
# Using cached qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
# Installing collected packages: qiskit-aer
# Successfully installed qiskit-aer-0.17.2
# Requirement already satisfied: qiskit-aer in /usr/local/lib/python3.12/dist-packages (0.17.2)
# Requirement already satisfied: qiskit>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (2.1.2)
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (2.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (1.16.1)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer) (0.17.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer) (5.5.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer) (4.15.0)

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, transpile
from qiskit.circuit.library import XGate, ZGate
from qiskit_aer import AerSimulator

# --- Setup Registers ---
q = QuantumRegister(9, 'data')         # 9 data qubits
anc = QuantumRegister(6, 'anc')        # 6 ancilla qubits
c_syndrome = ClassicalRegister(6, 'syndrome')  # For syndrome measurement
c_final = ClassicalRegister(1, 'final')        # For final logical qubit measurement

qc = QuantumCircuit(q, anc, c_syndrome, c_final)
sim = AerSimulator()

# --- Step 1: Encode logical |+> state ---
qc.h(q[0])               # Prepare |+⟩
qc.cx(q[0], q[3])        # Phase-flip protection: replicate
qc.cx(q[0], q[6])
for i in [0, 3, 6]:      # Bit-flip protection within each triplet
    qc.cx(i, i+1)
    qc.cx(i, i+2)
qc.barrier()

# --- Step 2: Inject optional error ---
# Uncomment one to test error correction
#qc.x(q[4])  # Bit-flip in middle of first triplet
#qc.z(q[7])  # Phase-flip in middle of third triplet
#qc.y(q[1])  # Bit + phase flip

qc.barrier()

# --- Step 3: Syndrome measurement (Bit flips) ---

# Triplet 1 (q0-q2)
qc.cx(q[0], anc[0])
qc.cx(q[1], anc[0])
qc.cx(q[2], anc[0])
qc.measure(anc[0], c_syndrome[0])
qc.reset(anc[0])

# Triplet 2 (q3-q5)
qc.cx(q[3], anc[1])
qc.cx(q[4], anc[1])
qc.cx(q[5], anc[1])
qc.measure(anc[1], c_syndrome[1])
qc.reset(anc[1])

# Triplet 3 (q6-q8)
qc.cx(q[6], anc[2])
qc.cx(q[7], anc[2])
qc.cx(q[8], anc[2])
qc.measure(anc[2], c_syndrome[2])
qc.reset(anc[2])

qc.barrier()

# --- Step 4: Syndrome measurement (Phase flips) ---

# q0 vs q3
qc.h(q[0])
qc.h(q[3])
qc.cx(q[0], anc[3])
qc.cx(q[3], anc[3])
qc.measure(anc[3], c_syndrome[3])
qc.reset(anc[3])
qc.h(q[0])
qc.h(q[3])

# q3 vs q6
qc.h(q[3])
qc.h(q[6])
qc.cx(q[3], anc[4])
qc.cx(q[6], anc[4])
qc.measure(anc[4], c_syndrome[4])
qc.reset(anc[4])
qc.h(q[3])
qc.h(q[6])

# q0 vs q6
qc.h(q[0])
qc.h(q[6])
qc.cx(q[0], anc[5])
qc.cx(q[6], anc[5])
qc.measure(anc[5], c_syndrome[5])
qc.reset(anc[5])
qc.h(q[0])
qc.h(q[6])

qc.barrier()

from qiskit.circuit import Gate

# --- Step 5: Conditional Error Correction ---

# Bit-flip corrections
with qc.if_test((c_syndrome, int('100000', 2))):
    qc.x(q[0])

with qc.if_test((c_syndrome, int('010000', 2))):
    qc.x(q[3])

with qc.if_test((c_syndrome, int('001000', 2))):
    qc.x(q[6])

# Phase-flip corrections
with qc.if_test((c_syndrome, int('000100', 2))):
    qc.z(q[0])

with qc.if_test((c_syndrome, int('000010', 2))):
    qc.z(q[3])

with qc.if_test((c_syndrome, int('000001', 2))):
    qc.z(q[6])


# --- Step 6: Decode logical qubit ---
for i in [0, 3, 6]:
    qc.cx(i, i+1)
    qc.cx(i, i+2)

qc.cx(q[0], q[3])
qc.cx(q[0], q[6])
qc.h(q[0])
qc.measure(q[0], c_final[0])

# --- Step 7: Run ---
tqc = transpile(qc, sim)
result = sim.run(tqc, shots=1024).result()
counts = result.get_counts()

# --- Step 8: Parse & Print Results ---

# Format: final_bit syndrome_bitstring (e.g., '0 101000')
syndrome_counts = {}
final_counts = {}

for bitstring, count in counts.items():
    bits = bitstring.replace(' ', '')
    final_bit = bits[0]
    syndrome_bits = bits[1:]

    syndrome_counts[syndrome_bits] = syndrome_counts.get(syndrome_bits, 0) + count
    final_counts[final_bit] = final_counts.get(final_bit, 0) + count

print("Syndrome bitstring counts:")
for s, c in sorted(syndrome_counts.items()):
    print(f"{s}: {c}")

print("\nFinal logical qubit measurement counts (X basis):")
for f, c in sorted(final_counts.items()):
    print(f"{f}: {c}")
# Out:
# Syndrome bitstring counts:
# 000001: 110
# 000110: 120
# 011001: 130
# 011110: 138
# 101001: 119
# 101110: 124
# 110001: 137
# 110110: 146
#
# Final logical qubit measurement counts (X basis):
# 0: 497
# 1: 527
